# %% [markdown]
# # Seaborn
# * Seaborn is a data visualization library built on top of Matplotlib.
# * It provides a high-level interface for creating aesthetically pleasing statistical graphics.
# * Seaborn is particularly useful for exploring and visualizing datasets. allowing users to gain insights into their data quickly and effectively.
# * One of the key features of Seaborn is, its ability to create visually appealing plots with minimal code.
# * It offers a wide range of plot types, including
#     * scatter plots
#     * line plots
#     * bar plots
#     * histograms
#     * box plots
#     * violin plots and more...

# %%
import seaborn as sns

# %% [markdown]
# # Seaborn - dataset
# * Seabom comes with several datasets that are built-in and can be directly accessed for visualization and analysis purposes.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df)

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df, fit_reg = False)

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df, fit_reg = False, hue = "sex")

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df, fit_reg = False, hue = "sex", col = "smoker")

# %%
df["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["time"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.lmplot(x = "total_bill", y = "tip", data = df, hue = "sex", col = "smoker", row = "time")

# %% [markdown]
# # Box plot
# * A box plot (also known as a box-and-whisker plot) is a graphical representation of the distribution of a dataset based on five summary statistics
#     * minimum
#     * first quartile (QI)
#     * median (Q2)
#     * third quartile (Q3)
#     * maximum
# * It is useful for detecting outliers and comparing distributions between different groups or categories.

# %%
sns.boxplot(df["tip"])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(x = "tip", y = "day", data = df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.boxplot(x = "tip", y = "day", data = df, hue = "smoker")
# Out:
# <Axes: xlabel='tip', ylabel='day'>
