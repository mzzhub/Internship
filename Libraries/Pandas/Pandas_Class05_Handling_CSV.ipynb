# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv')
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0        4
# 1         MBBS    NaN        6
# 2         ARTS    7.0        8
# 3    MALAYALAM    NaN        4

# %%
# to skip first indicated rows.
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', skiprows=2)
df
# Out:
#         MBBS  Unnamed: 1  6
# 0       ARTS         7.0  8
# 1  MALAYALAM         NaN  4

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', index_col="Label")
df
# Out:
#              maths  english
# Label
# ENGINEERING    3.0        4
# MBBS           NaN        6
# ARTS           7.0        8
# MALAYALAM      NaN        4

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', dtype={"english":np.float16})
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0      4.0
# 1         MBBS    NaN      6.0
# 2         ARTS    7.0      8.0
# 3    MALAYALAM    NaN      4.0

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv')
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0        4
# 1         MBBS    NaN        6
# 2         ARTS    7.0        8
# 3    MALAYALAM    NaN        4

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', names=["A","B","C","D"])
df
# Out:
#              A      B        C   D
# 0        Label  maths  english NaN
# 1  ENGINEERING      3        4 NaN
# 2         MBBS    NaN        6 NaN
# 3         ARTS      7        8 NaN
# 4    MALAYALAM    NaN        4 NaN

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', header=0)
df
# Out:
#          Label  maths  english
# 0  ENGINEERING    3.0        4
# 1         MBBS    NaN        6
# 2         ARTS    7.0        8
# 3    MALAYALAM    NaN        4

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/expor_dataframe.csv', usecols=["maths","english"])
df
# Out:
#    maths  english
# 0    3.0        4
# 1    NaN        6
# 2    7.0        8
# 3    NaN        4

# %%
two = pd.DataFrame(
    {
        'id':[1,2,3,4,5,7],
        'Name':['Billy','Brian','Bran','Bryce','Betty','ramu'],
        'subject_id':['sub2','sub4','sub8','sub6','sub5','sub9'],
        'Marks_scored':[89,80,79,97,88,56],'class':[1,23,4,5,5,6]
    },
    index=[1,2,3,4,5,7])

three = pd.DataFrame(
    {
        'id':[1,2,3,4,5,6],
        'Name':['Billy','Brian','Bran','Bryce','Betty','sarang'],
        'subject_id':['sub2','sub4','sub3','sub6','sub5','sub7'],
        'Marks_scored':[89,80,79,97,88,76],
        'roll no':[1,23,4,5,5,6]
    },
    index=[1,2,3,4,5,6])

# %%
two
# Out:
#    id   Name subject_id  Marks_scored  class
# 1   1  Billy       sub2            89      1
# 2   2  Brian       sub4            80     23
# 3   3   Bran       sub8            79      4
# 4   4  Bryce       sub6            97      5
# 5   5  Betty       sub5            88      5
# 7   7   ramu       sub9            56      6

# %%
three
# Out:
#    id    Name subject_id  Marks_scored  roll no
# 1   1   Billy       sub2            89        1
# 2   2   Brian       sub4            80       23
# 3   3    Bran       sub3            79        4
# 4   4   Bryce       sub6            97        5
# 5   5   Betty       sub5            88        5
# 6   6  sarang       sub7            76        6

# %%
data = pd.concat([two,three], ignore_index=True)

# %%
data
# Out:
#     id    Name subject_id  Marks_scored  class  roll no
# 0    1   Billy       sub2            89    1.0      NaN
# 1    2   Brian       sub4            80   23.0      NaN
# 2    3    Bran       sub8            79    4.0      NaN
# 3    4   Bryce       sub6            97    5.0      NaN
# 4    5   Betty       sub5            88    5.0      NaN
# 5    7    ramu       sub9            56    6.0      NaN
# 6    1   Billy       sub2            89    NaN      1.0
# 7    2   Brian       sub4            80    NaN     23.0
# 8    3    Bran       sub3            79    NaN      4.0
# 9    4   Bryce       sub6            97    NaN      5.0
# 10   5   Betty       sub5            88    NaN      5.0
# 11   6  sarang       sub7            76    NaN      6.0

# %%
data.to_csv('student.csv')

# %%
data.isna()
# Out:
#        id   Name  subject_id  Marks_scored  class  roll no
# 0   False  False       False         False  False     True
# 1   False  False       False         False  False     True
# 2   False  False       False         False  False     True
# 3   False  False       False         False  False     True
# 4   False  False       False         False  False     True
# 5   False  False       False         False  False     True
# 6   False  False       False         False   True    False
# 7   False  False       False         False   True    False
# 8   False  False       False         False   True    False
# 9   False  False       False         False   True    False
# 10  False  False       False         False   True    False
# 11  False  False       False         False   True    False

# %%
data.isna().any()
# Out:
# id              False
# Name            False
# subject_id      False
# Marks_scored    False
# class            True
# roll no          True
# dtype: bool

# %%
data.isna().any().sum()
# Out:
# 2

# %%
data.isna().sum()
# Out:
# id              0
# Name            0
# subject_id      0
# Marks_scored    0
# class           6
# roll no         6
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id              0
# Name            0
# subject_id      0
# Marks_scored    0
# class           6
# roll no         6
# dtype: int64

# %%
((data.isna().sum())/len(data))*100
# Out:
# id               0.0
# Name             0.0
# subject_id       0.0
# Marks_scored     0.0
# class           50.0
# roll no         50.0
# dtype: float64

# %%
data.fillna(0)
# Out:
#     id    Name subject_id  Marks_scored  class  roll no
# 0    1   Billy       sub2            89    1.0      0.0
# 1    2   Brian       sub4            80   23.0      0.0
# 2    3    Bran       sub8            79    4.0      0.0
# 3    4   Bryce       sub6            97    5.0      0.0
# 4    5   Betty       sub5            88    5.0      0.0
# 5    7    ramu       sub9            56    6.0      0.0
# 6    1   Billy       sub2            89    0.0      1.0
# 7    2   Brian       sub4            80    0.0     23.0
# 8    3    Bran       sub3            79    0.0      4.0
# 9    4   Bryce       sub6            97    0.0      5.0
# 10   5   Betty       sub5            88    0.0      5.0
# 11   6  sarang       sub7            76    0.0      6.0

# %%
df = pd.read_csv("/content/student.csv")
df
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  class  roll no
# 0            0   1   Billy       sub2            89    1.0      NaN
# 1            1   2   Brian       sub4            80   23.0      NaN
# 2            2   3    Bran       sub8            79    4.0      NaN
# 3            3   4   Bryce       sub6            97    5.0      NaN
# 4            4   5   Betty       sub5            88    5.0      NaN
# 5            5   7    ramu       sub9            56    6.0      NaN
# 6            6   1   Billy       sub2            89    NaN      1.0
# 7            7   2   Brian       sub4            80    NaN     23.0
# 8            8   3    Bran       sub3            79    NaN      4.0
# 9            9   4   Bryce       sub6            97    NaN      5.0
# 10          10   5   Betty       sub5            88    NaN      5.0
# 11          11   6  sarang       sub7            76    NaN      6.0

# %%
df["class"].fillna(df["class"].mean(), inplace=True)
df
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored      class  roll no
# 0            0   1   Billy       sub2            89   1.000000      NaN
# 1            1   2   Brian       sub4            80  23.000000      NaN
# 2            2   3    Bran       sub8            79   4.000000      NaN
# 3            3   4   Bryce       sub6            97   5.000000      NaN
# 4            4   5   Betty       sub5            88   5.000000      NaN
# 5            5   7    ramu       sub9            56   6.000000      NaN
# 6            6   1   Billy       sub2            89   7.333333      1.0
# 7            7   2   Brian       sub4            80   7.333333     23.0
# 8            8   3    Bran       sub3            79   7.333333      4.0
# 9            9   4   Bryce       sub6            97   7.333333      5.0
# 10          10   5   Betty       sub5            88   7.333333      5.0
# 11          11   6  sarang       sub7            76   7.333333      6.0

# %%
df = df.dropna()
df
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored     class  roll no
# 6            6   1   Billy       sub2            89  7.333333      1.0
# 7            7   2   Brian       sub4            80  7.333333     23.0
# 8            8   3    Bran       sub3            79  7.333333      4.0
# 9            9   4   Bryce       sub6            97  7.333333      5.0
# 10          10   5   Betty       sub5            88  7.333333      5.0
# 11          11   6  sarang       sub7            76  7.333333      6.0

# %%
df = pd.read_csv("/content/student.csv")
df
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  class  roll no
# 0            0   1   Billy       sub2            89    1.0      NaN
# 1            1   2   Brian       sub4            80   23.0      NaN
# 2            2   3    Bran       sub8            79    4.0      NaN
# 3            3   4   Bryce       sub6            97    5.0      NaN
# 4            4   5   Betty       sub5            88    5.0      NaN
# 5            5   7    ramu       sub9            56    6.0      NaN
# 6            6   1   Billy       sub2            89    NaN      1.0
# 7            7   2   Brian       sub4            80    NaN     23.0
# 8            8   3    Bran       sub3            79    NaN      4.0
# 9            9   4   Bryce       sub6            97    NaN      5.0
# 10          10   5   Betty       sub5            88    NaN      5.0
# 11          11   6  sarang       sub7            76    NaN      6.0

# %%
df1 = df.bfill()
df1
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  class  roll no
# 0            0   1   Billy       sub2            89    1.0      1.0
# 1            1   2   Brian       sub4            80   23.0      1.0
# 2            2   3    Bran       sub8            79    4.0      1.0
# 3            3   4   Bryce       sub6            97    5.0      1.0
# 4            4   5   Betty       sub5            88    5.0      1.0
# 5            5   7    ramu       sub9            56    6.0      1.0
# 6            6   1   Billy       sub2            89    NaN      1.0
# 7            7   2   Brian       sub4            80    NaN     23.0
# 8            8   3    Bran       sub3            79    NaN      4.0
# 9            9   4   Bryce       sub6            97    NaN      5.0
# 10          10   5   Betty       sub5            88    NaN      5.0
# 11          11   6  sarang       sub7            76    NaN      6.0

# %%
df2 = df.ffill()
df2
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  class  roll no
# 0            0   1   Billy       sub2            89    1.0      NaN
# 1            1   2   Brian       sub4            80   23.0      NaN
# 2            2   3    Bran       sub8            79    4.0      NaN
# 3            3   4   Bryce       sub6            97    5.0      NaN
# 4            4   5   Betty       sub5            88    5.0      NaN
# 5            5   7    ramu       sub9            56    6.0      NaN
# 6            6   1   Billy       sub2            89    6.0      1.0
# 7            7   2   Brian       sub4            80    6.0     23.0
# 8            8   3    Bran       sub3            79    6.0      4.0
# 9            9   4   Bryce       sub6            97    6.0      5.0
# 10          10   5   Betty       sub5            88    6.0      5.0
# 11          11   6  sarang       sub7            76    6.0      6.0

# %%
df3 = df.ffill().bfill()
df3
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  class  roll no
# 0            0   1   Billy       sub2            89    1.0      1.0
# 1            1   2   Brian       sub4            80   23.0      1.0
# 2            2   3    Bran       sub8            79    4.0      1.0
# 3            3   4   Bryce       sub6            97    5.0      1.0
# 4            4   5   Betty       sub5            88    5.0      1.0
# 5            5   7    ramu       sub9            56    6.0      1.0
# 6            6   1   Billy       sub2            89    6.0      1.0
# 7            7   2   Brian       sub4            80    6.0     23.0
# 8            8   3    Bran       sub3            79    6.0      4.0
# 9            9   4   Bryce       sub6            97    6.0      5.0
# 10          10   5   Betty       sub5            88    6.0      5.0
# 11          11   6  sarang       sub7            76    6.0      6.0
