# %%
import pandas as pd

# %%
sgr = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Libraries/Pandas/shirpurGoldRefinery (1).csv')

# %%
sgr.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...

# %%
sgr.describe()
# Out:
#        Open Price  High Price   Low Price  Close Price         WAP  \
# count  248.000000  248.000000  248.000000   248.000000  248.000000
# mean   135.422984  139.308669  131.937500   135.355847  135.750863
# std     28.009005   29.544756   26.928558    28.071455   28.350022
# min     89.750000   91.850000   87.200000    89.400000   90.129585
# 25%    106.962500  109.200000  104.337500   106.625000  107.077529
# 50%    140.050000  142.475000  136.800000   139.825000  139.928758
# 75%    153.787500  158.462500  149.475000   154.500000  154.637432
# max    218.950000  233.600000  212.400000   218.150000  223.089049
#
#         No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count     248.000000     248.000000          2.480000e+02
# mean    15235.052419     221.181452          2.300500e+06
# std     27459.354379     334.516358          4.773709e+06
# min       211.000000       6.000000          2.503400e+04
# 25%      2880.750000      50.000000          3.370950e+05
# ...

# %%
sgr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       248 non-null    object
#  1   Open Price                 248 non-null    float64
#  2   High Price                 248 non-null    float64
#  3   Low Price                  248 non-null    float64
#  4   Close Price                248 non-null    float64
#  5   WAP                        248 non-null    float64
#  6   No.of Shares               248 non-null    int64
#  7   No. of Trades              248 non-null    int64
#  8   Total Turnover (Rs.)       248 non-null    float64
#  9   Deliverable Quantity       248 non-null    int64
#  10  % Deli. Qty to Traded Qty  248 non-null    float64
#  11  Spread High-Low            248 non-null    float64
#  12  Spread Close-Open          248 non-null    float64
# ...

# %%
sgr.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open
# 0               -1.7
# 1                0.8

# %%
sgr.at[0,'Date']
# Out:
# '29-December-2017'

# %%
sgr.iat[0,0]
# Out:
# '29-December-2017'

# %%
type(sgr.iat[0,0])
# Out:
# str

# %%
# creating a new column
sgr['Time_Stamp'] = pd.to_datetime(sgr['Date'])

# %%
# updating the existing column
# sgr['Date'] = pd.to_datetime(sgr['Date'])

# %%
sgr.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...

# %%
sgr.iat[0,13]
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
type(sgr.iat[0,13])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
sgr.Time_Stamp
# Out:
# 0     2017-12-29
# 1     2017-12-28
# 2     2017-12-27
# 3     2017-12-26
# 4     2017-12-22
#          ...
# 243   2017-01-06
# 244   2017-01-05
# 245   2017-01-04
# 246   2017-01-03
# 247   2017-01-02
# Name: Time_Stamp, Length: 248, dtype: datetime64[ns]

# %%
sgr.Time_Stamp.max()
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
sgr['Day'] = pd.DatetimeIndex(sgr['Time_Stamp']).day
sgr['Month'] = pd.DatetimeIndex(sgr['Time_Stamp']).month
sgr['Year'] = pd.DatetimeIndex(sgr['Time_Stamp']).year

# %%
sgr.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...
