# %% [markdown]
# # **Model Parameters**
#     def myfunction(fname, lname):
#        print(fname + " " + lname)
#
#     myfunction("Peter", "Parker")
# * As we know that there are parameters that are internally learned from the given dataset and derived from the dataset,they are represented in making predictions, classifications etc. These are so-called **Model Parameters**
# * They may vary with respect to the nature of the data we couldn't control.
# * Because it depends on the data like $m$ (slope) and $c$ ($y$ - intercept) in linear equation,which are the values of coefficents learned from the given dataset.

# %% [markdown]
# # **Hyper Parameters**
# * Some set of parameters that are used to control the behaviour of the model or algorithm and adjustable in order to obtain an improvised model with optimal performance is called **Hyperparameters**
# * Examples
#     * In KNN, the value of $k$ is changeble (euclidiean or manhatten)
#     * In decision tree,
#         * gini index (entropy)
#         * information gain (max depth / max split value)
# * The best model algorithm(s) will sparkle if your choice of Hyperparameters.

# %% [markdown]
# # **Hyperparameter Tuning**
# * Hyper parameter Tuning refers to the process of choosing the optimum set of hyperparameters for a machine learning model.
# * This process is also called **hyperparameter optimization**.
#
# **PARAMETERS**
# * Parameters in machine learning and deep leaming are the values your leaming algorithm can change independently as it learns.
# * Two types:
#     1. **Internal Parameters**
#         * A model hyperparameter is a configuration that is external to the model and whose value cannot be estimated from data.
#         * Hyperparamters are parameters whose values control the learning process.
#         * These are adjustable parameters used to obtain an optimal model.
#     2. **External Parameters**
#         * A model parameter is a variable of the selected model which can be estimated by fifing the given data to model.
#         * A model hyperparameter is the parameter whose value is set before the model starts training.
#         * They cannot be learned by fitting the model to the data.
#
# * Two generic approaches to search effectively in the HP space
#     1. **GridSearch CV**
#     2. **RandomSearch CV**
#
# # **GridSearch**
# * To implement the Grid-Search, we have a Scikit-Learn library
# called GridSearchCV.
# * The computaional time would be long, but it would reduce
# the manual efforts by avoiding the number of lines of code.
# * Library itself perform the search operations and return the performing model and its score in which each model are build for each permutation of a given hyperparameter.
# * Internally it would be evaluated and ranked across the given cross-validation folds.
#     * **Cross-Validation :**
#         * Cross Validation is a technique used in machine learning to evaluate the performance of a model on unseen data.
#         * It involves dividing the available data into multiple folds or subsets.
#         * Using one of these folds as a validation set, and training the model on the remaining folds.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
